# %%
# %%bash
# pip list | grep prompt-toolkitd
# Out:
# prompt-toolkit     1.0.16

# %%
df = sqlContext.read.format("parquet").option("inferSchema", "true").load("s3://paid-qubole/default-datasets/timeseries/")
# Out:
# Kernel Id: d422b3ab-4fc4-4507-a0ad-bd25cdfb7297
# Starting Spark application
# <table>
# <tr><th>ID</th><th>Name</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>0</td><td>scoped_mukundag__qubole_default</td><td>application_1570173269656_0001</td><td>pyspark</td><td>idle</td><td><a class="jpq-ui-links" data-url="/cluster-proxy?clusterInst=57946&encodedUrl=http%3A%2F%2F10.45.114.167%3A8088%2Fproxy%2Fapplication_1570173269656_0001%2F" data-action="spark-ui:open" href="javascript:void(0)" onClick="return false;">Link</a></td><td><a class="jpq-ui-links" data-url="/cluster-proxy?clusterInst=57946&encodedUrl=http%3A%2F%2F10.183.35.13%3A8042%2Fnode%2Fcontainerlogs%2Fcontainer_1570173269656_0001_01_000001%2Fmukundag" data-action="driver-log:open" href="javascript:void(0)" onClick="return false;">Link</a></td><td>✔</td></tr></table>
# SparkSession available as 'spark'.
# ...

# %%
 df.createOrReplaceTempView("deutsche")
# Out:
# <div class="progress-ipython-shell"></div>

# %%
# %%sql
# select * from deutsche limit 10
# Out:
# <div class="progress-ipython-shell"></div>
# <div class="progress-ipython-shell"></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-fa14c3d09c9d> in <module>()
# ----> 1 get_ipython().run_cell_magic('sql', '', 'select * from deutsche limit 10')
#
# /usr/lib/virtualenv/jupyterlab/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2165             magic_arg_s = self.var_expand(line, stack_depth)
#    2166             with self.builtin_trap:
# -> 2167                 result = fn(magic_arg_s, cell)
#    2168             return result
#    2169
#
# </usr/lib/virtualenv/jupyterlab/local/lib/python3.6/site-packages/decorator.py:decorator-gen-124> in sql(self, *args, **kwargs)
#
# /usr/lib/virtualenv/jupyterlab/local/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
# ...

# %%
# %%sql
# select * from deutsche limit 10
# Out:
# <div class="progress-ipython-shell"></div>
# <div class="progress-ipython-shell"></div>
# ...
# Output()

# %%
# %%local
# import pandas as pd
# df = pd.DataFrame({'a': [1,2,3], 'b': [1,2,3], 'c': ["hi","hello","hey"]})
#
# from autovizwidget.widget.utils import display_dataframe
# display_dataframe(df)
# Out:
# ...
# Output()
# AutoVizWidget()

# %%
sh
