# %%
from IPython.display import display, HTML
df = sc.parallelize([{"arg1": "", "arg2": ""},{"arg1": "", "arg2": ""},{"arg1": "", "arg2": ""}]).toDF()

df
# Out:
# <div class="progress-ipython-shell"></div>
# DataFrame[arg1: string, arg2: string]

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import pandas as pd

plt.figure(num=None, figsize=(10, 10), dpi=100)

df = pd.read_csv("https://raw.githubusercontent.com/arangodb/example-datasets/master/Cities/GeoLiteCity.csv")

col1 = df['longitude']
col2 = df['latitude']
plt.scatter(col1, col2, edgecolors='r')
# Out:
# <div class="progress-ipython-shell"></div>
# Implement enable_gui in a subclass
# Traceback (most recent call last):
#   File "/usr/lib/envs/env-7420-ver-6660-a-4.2.9-py-2.7.13/lib/python2.7/site-packages/matplotlib/pyplot.py", line 2534, in <module>
#     install_repl_displayhook()
#   File "/usr/lib/envs/env-7420-ver-6660-a-4.2.9-py-2.7.13/lib/python2.7/site-packages/matplotlib/pyplot.py", line 166, in install_repl_displayhook
#     ip.enable_gui(ipython_gui_name)
#   File "/usr/lib/envs/env-7420-ver-6660-a-4.2.9-py-2.7.13/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2911, in enable_gui
#     raise NotImplementedError('Implement enable_gui in a subclass')
# NotImplementedError: Implement enable_gui in a subclass

# %%
vertices = spark.createDataFrame([
  ("a", "Alice", 34),
  ("b", "Bob", 36),
  ("c", "Charlie", 30),
  ("d", "David", 29),
  ("e", "Esther", 32),
  ("f", "Fanny", 36),
  ("g", "Gabby", 60)], ["id", "name", "age"])

edges = spark.createDataFrame([
  ("a", "b", "friend"),
  ("b", "c", "follow"),
  ("c", "b", "follow"),
  ("f", "c", "follow"),
  ("e", "f", "follow"),
  ("e", "d", "friend"),
  ("d", "a", "friend"),
  ("a", "e", "friend")
], ["src", "dst", "relationship"])
edges.show()
# Out:
# <div class="progress-ipython-shell"></div>
# +---+---+------------+
# |src|dst|relationship|
# +---+---+------------+
# |  a|  b|      friend|
# |  b|  c|      follow|
# |  c|  b|      follow|
# |  f|  c|      follow|
# |  e|  f|      follow|
# |  e|  d|      friend|
# |  d|  a|      friend|
# |  a|  e|      friend|
# +---+---+------------+

# %%
# Out:
# <div class="progress-ipython-shell"></div>
# 'SparkContext' object has no attribute 'sqlContext'
# Traceback (most recent call last):
# AttributeError: 'SparkContext' object has no attribute 'sqlContext'
